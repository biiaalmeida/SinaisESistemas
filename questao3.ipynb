# %% [markdown]
# ##  Questão 3
#
# Um modulador em amplitude comercial é definido pela seguinte relação de entrada $x(t)$ e saída $y(t)$:
#
# $$
# y(t) = (A+ x(t))\cos(2\pi f_c t)
# $$
#
#
# Determine, de forma computacional, a sáida para $ 0 \leq t \leq 0,1$ do sistema modulador em amplitude quando a entrada é igual à:
#
# $$
# x(t) = \cos(2\pi f_m t)
# $$
#
# sendo $f_m = 500$ Hz. Considere $A = 1,5$ e $f_c = 5000$ Hz. Plote a forma de onda do sinal de saída.
#
# ---

# %% [markdown]
# ## 3.1 Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3.2 Parâmetros

# %%
t_inicio = 0
t_fim = 0.01
npoints = 10_000

t = np.linspace(t_inicio, t_fim, npoints)

a = 1.5

Fm = 50
x = np.cos(2*np.pi*Fm*t)

Fc = 500
y = (a+x)*np.cos(2*np.pi*Fc*t)

# %% [markdown]
# ## 3.3 Plots

# %%
plt.figure(figsize=(7,4))
plt.subplot(2,1,1)
plt.plot(t,x)
plt.xlabel('$t$')
plt.title('$x(t)$')
plt.grid()
plt.xlim([t_inicio, t_fim])

plt.subplot(2,1,2)
plt.plot(t,y)
plt.xlabel('$t$')
plt.title('$y(t)$')
plt.grid()
plt.xlim([t_inicio, t_fim])

plt.tight_layout()
plt.show()
